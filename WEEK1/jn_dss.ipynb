# %% [markdown]
# ##### 명령모드
#
# - 셀지우기 : dd, x
# - 현재 선택된 셀 위로 셀 삽입 : a
# - 현재 선택된 셀 아래로 셀 삽입 : b
# - 현재 셀의 라인 보기 : l
# - 마크다운으로 변환 : m
# - 코드로 변환 : y

# %%
"python"
# Out:
# 'python'

# %%
"test"
# Out:
# 'test'

# %%
"science"
# Out:
# 'science'

# %%
"dss"
# Out:
# 'dss'

# %% [markdown]
# ##### 편집모드
#
# - ctrl + Enter : 코드 실행되고 행 이동이 없음
# - shift + Enter : 코드 실행되고 아래 행으로 이동
# - alt + Enter : 코드가 실행되고 아래 셀이 생성
#
# - tab : 자동완성
# - shift + tab : 내부정보 보기
# - ? + 실행 : 내보정보 보기
# - ?? + 실행 : 코드 소스를 보기

# %%
def sum(a, b):
    """ test docstring """
    return a + b

# %%
sum??

# %%
"python"
# Out:
# 'python'

# %%
"test"
# Out:
# 'test'

# %%
def sum(a, b):
    """
    test docstring
    """
    return a + b

# %%
sum?

# %%
sum??

# %%
sum(1, 3)

# %% [markdown]
# #### Markdown

# %% [markdown]
# 머릿말 heading `#`
#
# # Heading
# ## Heading
# ### Heading
# #### Heading
# ##### Heading

# %% [markdown]
# 인용 `>`, `>>`
#
# > dss
# >> data science

# %% [markdown]
# 리스트 `-`, `*`
#
# - data1
# - data2
#     - data2-1
#     - data2-2
# - data3

# %% [markdown]
# 코드블럭
#
# `- list`
#
#
# ```
# - list1
# - list2
# ```

# %% [markdown]
# 링크 link
#
# http://yahoo.com
#
# http://google.com
#
# `[구글](http://google.com)`
#
# [구글](http://google.com)

# %% [markdown]
# 가로선 긋기
#
# `---`
#
# ---

# %% [markdown]
# ### Magic Command

# %% [markdown]
# - `%`
# - %(cmd) : 한줄 수행
# - %%(cmd) : 셀 단위 수행
# - %(cmd)? : 커멘드에대한 설명

# %%
# %pwd
# Out:
# '/home/jk/Downloads'

# %%
# %ls
# Out:
# 01_basic_syntax.ipynb            Iris.csv
# 02_condition_loop_input.ipynb    jn_dss.ipynb
# 180108_강의노트.zip              rstudio-xenial-1.1.383-amd64 (1).deb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64.deb
# enter/

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
a = 1

# %%
a
# Out:
# 'python'

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# a          int         1
# sum        function    <function sum at 0x10a85d6a8>

# %%
a = "python"

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
# %%time
1 + 3
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 7.63 µs
# 4

# %%
# %%timeit
1 + 3
# Out:
# 12.1 ns ± 0.159 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
# %%writefile test.py
print(2 + 3)
# Out:
# Writing test.py

# %%
# %ls
# Out:
# 01_basic_syntax.ipynb            Iris.csv
# 02_condition_loop_input.ipynb    jn_dss.ipynb
# 180108_강의노트.zip              rstudio-xenial-1.1.383-amd64 (1).deb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64.deb
# dss.py                           test.py
# enter/

# %%
# %run test.py
# Out:
# 5

# %%
# %load test.py
print(2 + 3)
# Out:
# 5

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %profile  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %%
# %history?

# %% [markdown]
# ### Shell Command

# %%
! ls
# Out:
# 01_basic_syntax.ipynb		 Iris.csv
# 02_condition_loop_input.ipynb	 jn_dss.ipynb
# 180108_강의노트.zip		 rstudio-xenial-1.1.383-amd64 (1).deb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64.deb
# dss.py				 test.py
# enter

# %%
! echo "python"
# Out:
# python

# %%
! touch dss.py

# %%
! ls
# Out:
# 01_basic_syntax.ipynb		 Iris.csv
# 02_condition_loop_input.ipynb	 jn_dss.ipynb
# 180108_강의노트.zip		 rstudio-xenial-1.1.383-amd64 (1).deb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64.deb
# dss.py				 test.py
# enter

# %%
file_list = ! ls

# %%
file_list
# Out:
# ['01_basic_syntax.ipynb',
#  '02_condition_loop_input.ipynb',
#  '180108_강의노트.zip',
#  'Anaconda3-5.0.1-Linux-x86_64.sh',
#  'dss.py',
#  'enter',
#  'Iris.csv',
#  'jn_dss.ipynb',
#  'rstudio-xenial-1.1.383-amd64 (1).deb',
#  'rstudio-xenial-1.1.383-amd64.deb',
#  'test.py']

# %%
! echo {file_list}
# Out:
# [01_basic_syntax.ipynb, 02_condition_loop_input.ipynb, 180108_강의노트.zip, Anaconda3-5.0.1-Linux-x86_64.sh, dss.py, enter, Iris.csv, jn_dss.ipynb, rstudio-xenial-1.1.383-amd64 (1).deb, rstudio-xenial-1.1.383-amd64.deb, test.py]

# %%
! cat test.py
# Out:
# print(2 + 3)

# %%
! mkdir python

# %%
! ls
# Out:
# 01_basic_syntax.ipynb		 Iris.csv
# 02_condition_loop_input.ipynb	 jn_dss.ipynb
# 180108_강의노트.zip		 python
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64 (1).deb
# dss.py				 rstudio-xenial-1.1.383-amd64.deb
# enter				 test.py

# %%
! rmdir python

# %%
! ls
# Out:
# 01_basic_syntax.ipynb		 Iris.csv
# 02_condition_loop_input.ipynb	 jn_dss.ipynb
# 180108_강의노트.zip		 rstudio-xenial-1.1.383-amd64 (1).deb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64.deb
# dss.py				 test.py
# enter

# %%
! cp test.py test2.py

# %%
! ls
# Out:
# 01_basic_syntax.ipynb		 Iris.csv
# 02_condition_loop_input.ipynb	 jn_dss.ipynb
# 180108_강의노트.zip		 rstudio-xenial-1.1.383-amd64 (1).deb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64.deb
# dss.py				 test2.py
# enter				 test.py

# %%
! cat test2.py
# Out:
# print(2 + 3)

# %%
! rm test2.py

# %%
! ls
# Out:
# 01_basic_syntax.ipynb		 Iris.csv
# 02_condition_loop_input.ipynb	 jn_dss.ipynb
# 180108_강의노트.zip		 rstudio-xenial-1.1.383-amd64 (1).deb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64.deb
# dss.py				 test.py
# enter

# %%
! mv test.py dss.py

# %%
! ls
# Out:
# 01_basic_syntax.ipynb		 enter
# 02_condition_loop_input.ipynb	 Iris.csv
# 180108_강의노트.zip		 jn_dss.ipynb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64 (1).deb
# dss.py				 rstudio-xenial-1.1.383-amd64.deb

# %%
! df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# udev            3.9G     0  3.9G   0% /dev
# tmpfs           785M  9.2M  776M   2% /run
# /dev/sda1       910G   14G  849G   2% /
# tmpfs           3.9G  9.5M  3.9G   1% /dev/shm
# tmpfs           5.0M  4.0K  5.0M   1% /run/lock
# tmpfs           3.9G     0  3.9G   0% /sys/fs/cgroup
# tmpfs           785M   76K  785M   1% /run/user/1000

# %%
! ps
# Out:
#   PID TTY          TIME CMD
#  2301 pts/11   00:00:00 sh
#  2302 pts/11   00:00:00 ps

# %%
! ps
# Out:
#   PID TTY          TIME CMD
#  2303 pts/11   00:00:00 sh
#  2304 pts/11   00:00:00 ps

# %%
(1) 아래 코드가 작성된 test.py 파일 생성 %%writefile
    def sum(a, b): 
        return a + b
(2) test.py가 생성되었는지 확인 
(3) test.py를 dss.py로 변경
(4) dss.py를 test.py로 복사 
(5) test.py 파일 로드 
(6) test.py 실행 (run 명령어 사용 또는 호출된 코드 실행) 
(7) dss.py 파일 삭제
(8) sum(1, 2) 실행
(9) sum(1, 2) 코드 실행시간 확인 
(10) 현재 선언된 변수 확인
(11) a = 1 변수 선언
(12) 선언된 변수 삭제
(13) 선언된 변수가 삭제되었는지 확인
# Out:
#   File "<ipython-input-45-20341520996b>", line 1
#     (1) 아래 코드가 작성된 test.py 파일 생성 %%writefile
#          ^
# SyntaxError: invalid syntax

# %%
# %%writefile test.py
def sum(a, b):
    return a + b
# Out:
# Writing test.py

# %%
! cat test.py
# Out:
# def sum(a, b):
#     return a + b

# %%
! ls
# Out:
# 01_basic_syntax.ipynb		 Iris.csv
# 02_condition_loop_input.ipynb	 jn_dss.ipynb
# 180108_강의노트.zip		 rstudio-xenial-1.1.383-amd64 (1).deb
# Anaconda3-5.0.1-Linux-x86_64.sh  rstudio-xenial-1.1.383-amd64.deb
# dss.py				 test.py
# enter

# %%
! mv test.py dss.py

# %%
! ls
# Out:
# basic_syntax.ipynb dss.py             jn_dss.ipynb

# %%
! cat dss.py
# Out:
# def sum(a, b):
#     return a + b

# %%
! cp dss.py test.py

# %%
! ls
# Out:
# basic_syntax.ipynb dss.py             jn_dss.ipynb       test.py

# %%
! cat test.py
# Out:
# def sum(a, b):
#     return a + b

# %%
# %load test.py
def sum(a, b):
    return a + b

# %%
# %run test.py

# %%
! rm dss.py

# %%
! ls
# Out:
# basic_syntax.ipynb jn_dss.ipynb       test.py

# %%
sum(1, 2)
# Out:
# 3

# %%
# %%timeit
sum(1, 2)
# Out:
# 126 ns ± 1.77 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# file_list   SList       ['basic_syntax.ipynb', 'd<...>jn_dss.ipynb', 'test.py']
# sum         function    <function sum at 0x10a7c6ae8>

# %%
a = 1

# %%
# %whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# a           int         1
# file_list   SList       ['basic_syntax.ipynb', 'd<...>jn_dss.ipynb', 'test.py']
# sum         function    <function sum at 0x10a7c6ae8>

# %%
b = "a"

# %%
# %whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# a           int         1
# b           str         a
# file_list   SList       ['basic_syntax.ipynb', 'd<...>jn_dss.ipynb', 'test.py']
# sum         function    <function sum at 0x10a7c6ae8>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %% [markdown]
# ##### expression

# %%
result = 1 + 3

# %%
result * 2
# Out:
# 8

# %%
1 + 3
# Out:
# 4

# %%
_ * 2
# Out:
# 8

# %%
"python"
# Out:
# 'python'

# %%
_ + " test"
# Out:
# 'python test'

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
