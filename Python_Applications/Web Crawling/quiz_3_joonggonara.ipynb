# %% [markdown]
# ##### 네이버 중고나라 크롤링
# - http://cafe.naver.com/joonggonara
# - 중고나라 검색 키워드를 입력받아 판매중인 상품에 대한 제목, 링크, 조회수, 등록날짜, 가격을 크롤링하여 데이터 프레임 만들기
# - 모바일 페이지를 활용하세요
#
#
# - get_total : 전체 데이터 갯수를 가져오는 함수
# - get_items : 아이템 리스트를 가져오는 함수
# - get_price : 상세 페이지에서 가격정보를 가져오는 함수
# - make_datas : 아이템을 데이터 리스트로 만드는 함수 (판매 중인 데이터만)
# - all_datas : 키워드를 입력받아 전체 데이터를 가져오는 함수

# %%
import requests
import pandas as pd 
from bs4 import BeautifulSoup

# %%
# 전체 데이터 갯수를 가져오는 함수
def get_total(keyword):
    pass

# 테스트 코드
get_total("트레이더스 에어프라이어")

# %%
# 아이템 리스트를 가져오는 함수
def get_items(keyword, page):
    pass

# 테스트 코드
items = get_items("트레이더스 에어프라이어", 1)    
len(items)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-4d25667ddee9> in <module>()
#       5 # 테스트 코드
#       6 items = get_items("트레이더스 에어프라이어", 1)
# ----> 7 len(items)
#
# TypeError: object of type 'NoneType' has no len()

# %%
# 상세 페이지에서 가격정보를 가져오는 함수
def get_price(link):
    pass
    
# 테스트 코드
link = "https://m.cafe.naver.com/ArticleRead.nhn?clubid=10050146&menuid=451&articleid=455147331&query=%ED%8A%B8%EB%A0%88%EC%9D%B4%EB%8D%94%EC%8A%A4+%EC%97%90%EC%96%B4%ED%94%84%EB%9D%BC%EC%9D%B4%EC%96%B4"
get_price(link)

# %%
# 아이템을 데이터 리스트로 만드는 함수
def make_datas(items):
    pass

# 테스트 코드
datas = make_datas(items)
len(datas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-b1aa6b5a3184> in <module>()
#       5 # 테스트 코드
#       6 datas = make_datas(items)
# ----> 7 len(datas)
#
# TypeError: object of type 'NoneType' has no len()

# %%
# 키워드를 입력받아 전체 데이터를 가져오는 함수
def all_datas(keyword):
    pass
    
# 테스트 코드
datas = all_datas("트레이더스 에어프라이어")
len(datas)
# Out:
# 98

# %%
# 데이터 프레임을 만드는 코드
datas = all_datas("트레이더스 에어프라이어")

columns = ["title", "link", "views", "date", "price"]
df = pd.DataFrame(datas, columns=columns)
df
# Out:
#                                                 title  \
# 0                                        트레이더스 에어프라이어
# 1                          이마트 트레이더스 에어 프라이어 사기 속지마세요
# 2                                        트레이더스 에어프라이어
# 3   비싼고가 에어프라이어 저렴히 드립니다(새상품)57000원 /이마트트레이더스 에어프라...
# 4                           이마트 트레이더스 에어프라이어 플러스 삽니다!
# 5                                트레이더스 에어프라이어 삽니다! 창원
# 6                                        트레이더스 에어프라이어
# 7                              트레이더스 에어프라이어 삽니나. (대구)
# 8                                트레이더스 에어프라이어 5.2L삽니다
# 9                       더 에어프라이어 플러스 이마트 트레이더스 제품 삽니다
# 10                             트레이더스 에어프라이어 울산직거래 삽니다
# 11                             울산,양산 트레이더스 에어프라이어 삽니다
# 12                             이마트 트레이더스 에어프라이어 사기 주의
# 13                           이마트 트레이더스 에어프라이어 플러스 삽니다
# 14                                  트레이더스 에어프라이어 삽니다.
# 15                                       트레이더스 에어프라이어
# 16                               이마트 트레이더스 에어프라이어(완료)
# 17                                   트레이더스 에어프라이어 삽니다
# 18                             트레이더스 에어프라이어 (미개봉 새제품)
# 19                         트레이더스 대용량 에어프라이어 팔아요(거래완료)
# 20                               이마트 트레이더스 에어프라이어 플러스
# 21                            이마트트레이더스 에어프라이어 새상품 팔아요
# 22              이마트 트레이더스 에어프라이어 플러스 AFG-1702T 98000원
# 23                                트레이더스 에어프라이어(안양,군포)
# 24                                   트레이더스 에어프라이어 미개봉
# 25                           트레이더스 에어프라이어 택포 105,000원
# 26                           트레이더스 에어프라이어 택포 105,000원
# 27                                    트레이더스 에어프라이어 새거
# 28                                 트레이더스 에어프라이어 사고싶어요
# 29                               트레이더스 에어프라이어 새제품 팔아요
# ..                                                ...
# 68                              트레이더스 에어프라이어 플러스 삽니다.
# 69                       이마트 트레이더스 에어프라이어 못 사서 짜증납니다.
# 70                                  트레이더스 에어프라이어 구합니다
# 71                               트레이더스 에어프라이어 사기꾼 보시오
# 72                               트레이더스 대용량 에어프라이어 구해요
# 73                               트레이더스 에어프라이어 플러스 삽니다
# 74                           이마트 트레이더스 에어프라이어 플러스 삽니다
# 75              (구미직거래)트레이더스 에어프라이어 대용량(AFG-1702T)구해요
# 76                                [판매완료] 트레이더스 에어프라이어
# 77                                  트레이더스 에어프라이어 구입방법
# 78                           트레이더스 에어프라이어(광명직거래구입원해요)
# 79                               이마트 트레이더스 대용량 에어프라이어
# 80                 이마트트레이더스 대용량 에어프라이어 구매하고 싶습니다.직거래로
# 81                        구해요-이마트트레이더스 에어프라이어 대용량 구해요
# 82                              트레이더스 에어프라이어 새상품 11만원
# 83                         트레이더스 에어프라이어 삽니다 afg-1702t
# 84                         트레이더스에어프라이어AFG-1702T미개봉새상품
# 85                  트레이더스 에어프라이어 구매대행 요청(일산에서 직거래 희망)
# 86                                       트레이더스 에어프라이어
# 87                                        트레이더스에어프라이어
# 88                           이마트 트레이더스 에어프라이어 플러스 대용량
# 89                             트레이더스 에어프라이어 플러스 구매합니다
# 90                이마트 트레이더스 에어프라이어 플러스(AFG-1702T) 대용량
# 91                                트레이더스 에어프라이어플러스 구해요
# 92                          (구함)트레이더스 에어프라이어 플러스 구해요.
# 93                     판매완료) 에어프라이어 트레이더스 대용량 박스채 새제품
# 94                         [삽니다]이마트 트레이더스 에어프라이어 삽니다~
# 95                         이마트 트레이더스 에어프라이어 플러스 구합니다.
# 96                           이마트 트레이더스 에어프라이어 플러스 구해여
# 97                            전주 이마트 트레이더스 에어프라이어 대용량
#
#                                                  link  views       date  \
# 0   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    111  18.03.05.
# 1   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    319  18.03.05.
# 2   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    249  18.03.05.
# 3   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    233  18.03.05.
# 4   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    258  18.03.05.
# 5   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    114  18.03.05.
# 6   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    291  18.03.04.
# 7   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    188  18.03.04.
# 8   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    172  18.03.04.
# 9   https://m.cafe.naver.com/ArticleRead.nhn?clubi...    269  18.03.03.
# 10  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    173  18.03.03.
# 11  https://m.cafe.naver.com/ArticleRead.nhn?clubi...     72  18.03.03.
# 12  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    767  18.03.02.
# 13  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    510  18.03.02.
# 14  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    225  18.03.02.
# 15  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    840  18.03.01.
# 16  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    535  18.03.01.
# 17  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    258  18.02.28.
# 18  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    255  18.02.28.
# 19  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    400  18.02.28.
# 20  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    989  18.02.27.
# 21  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    343  18.02.27.
# 22  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  1,537  18.02.27.
# 23  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    304  18.02.27.
# 24  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    162  18.02.27.
# 25  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    156  18.02.27.
# 26  https://m.cafe.naver.com/ArticleRead.nhn?clubi...     87  18.02.27.
# 27  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    208  18.02.27.
# 28  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    275  18.02.27.
# 29  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    229  18.02.27.
# ..                                                ...    ...        ...
# 68  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    470  18.02.01.
# 69  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  1,614  18.02.01.
# 70  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    423  18.01.25.
# 71  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  1,864  18.01.24.
# 72  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    427  18.01.23.
# 73  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    464  18.01.21.
# 74  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    650  18.01.16.
# 75  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  1,131  18.01.14.
# 76  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    568  18.01.12.
# 77  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  1,042  18.01.11.
# 78  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    245  18.01.10.
# 79  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  1,611  18.01.10.
# 80  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    591  18.01.05.
# 81  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    659  18.01.04.
# 82  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    505  18.01.03.
# 83  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    769  18.01.01.
# 84  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  1,408  18.01.01.
# 85  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    582  17.12.21.
# 86  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    516  17.12.21.
# 87  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    355  17.12.21.
# 88  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  3,020  17.12.21.
# 89  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    649  17.12.18.
# 90  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  4,395  17.12.16.
# 91  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    433  17.12.10.
# 92  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    384  17.12.10.
# 93  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    476  17.11.25.
# 94  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    404  17.11.23.
# 95  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    568  17.11.22.
# 96  https://m.cafe.naver.com/ArticleRead.nhn?clubi...  1,024  17.11.20.
# 97  https://m.cafe.naver.com/ArticleRead.nhn?clubi...    730  17.11.01.
#
#          price
# 0      110,000
# 1       12,345
# 2      110,000
# 3       57,000
# 4      100,000
# 5        2,000
# 6      110,000
# 7       95,000
# 8      110,000
# 9      110,000
# 10     100,000
# 11     100,000
# 12     123,456
# 13     110,000
# 14      95,000
# 15      95,000
# 16       3,000
# 17      10,000
# 18     105,000
# 19      84,800
# 20     100,000
# 21     120,000
# 22      98,000
# 23     100,000
# 24     110,000
# 25     105,000
# 26     105,000
# 27     110,000
# 28      90,000
# 29  12,121,212
# ..         ...
# 68      11,111
# 69     100,000
# 70     110,000
# 71      12,345
# 72     100,000
# 73     110,000
# 74     100,000
# 75     100,000
# 76       2,222
# 77       2,000
# 78       2,222
# 79       2,000
# 80     110,000
# 81      85,000
# 82     110,000
# 83       2,000
# 84     100,000
# 85     100,000
# 86       2,000
# 87     110,000
# 88       2,000
# 89     110,000
# 90       2,000
# 91     100,000
# 92      80,000
# 93   1,111,111
# 94       2,000
# 95       2,000
# 96      12,345
# 97     100,000
#
# [98 rows x 5 columns]
