# %% [markdown]
# ### Pandas Visualization
# - https://pandas.pydata.org/pandas-docs/stable/visualization.html

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
plt.show()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
df.tail()
# Out:
#                     A          B          C          D
# 2002-09-22 -17.569410  51.143706  32.244750  18.047198
# 2002-09-23 -14.973353  49.515257  32.497065  15.780827
# 2002-09-24 -14.390607  48.250503  33.498655  16.140333
# 2002-09-25 -15.624181  48.289849  33.371809  16.498790
# 2002-09-26 -14.248526  46.108959  34.864725  13.499587

# %%
df.plot()
plt.legend(loc='best')
plt.show()

# %% [markdown]
# - bar
# - pie
# - scatter

# %% [markdown]
# ##### Seaborn data set
# - https://github.com/mwaskom/seaborn-data

# %%
iris = sns.load_dataset("iris")
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
iris[:10].plot()
plt.show()

# %%
iris[:10].plot(kind="bar")
plt.show()

# %%
iris_pie = iris.species.value_counts()
iris_pie.plot.pie(autopct='%d%%') # decimal %
plt.axis('equal')
plt.show()

# %%
iris.plot.scatter(x='sepal_length', y='sepal_width')
plt.show()

# %%
setosa = iris[iris["species"] == "setosa"]
versicolor = iris[iris["species"] == "versicolor"]
virginica = iris[iris["species"] == "virginica"]

# %%
ax_obj = setosa.plot.scatter(x='sepal_length', y='sepal_width', c="red")
versicolor.plot.scatter(x='sepal_length', y='sepal_width', c="blue", ax=ax_obj)
virginica.plot.scatter(x='sepal_length', y='sepal_width', c="black", ax=ax_obj)
plt.show()
