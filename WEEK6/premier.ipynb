# %% [markdown]
# # Premier table

# %% [markdown]
# https://www.premierleague.com/tables

# %%
# parser.py
import requests
from bs4 import BeautifulSoup
import json
import os

# HTTP GET Request
req = requests.get('https://www.premierleague.com/tables')

# HTML 소스 가져오기
html = req.text
# BeautifulSoup으로 html소스를 python객체로 변환하기
# 첫 인자는 html소스코드, 두 번째 인자는 어떤 parser를 이용할지 명시.
# 이 글에서는 Python 내장 html.parser를 이용했다.
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# body > h3:nth-child(4)

# %%
my_titles = soup.select('#mainContent')

# %%
my_titles
# Out:
# [<main id="mainContent" tabindex="0">
#  <!-- /131332370/GeneralTakeover -->
#  <div class="DFP-takeover" id="div-gpt-ad-1503491171981-0" style="display: none;">
#  <section class="navBar">
#  <a class="plLogo" href="#!" id="logoClose">
#  <img alt="Premier League Logo" src="http://cdn.pulselive.com/test/client/pl/test/i/elements/premier-league-logo-header-full.png"/>
#  </a>
#  </section>
#  <a class="closeBtn" href="#!" id="advertClose">Close Advert</a>
#  <script type="text/javascript">
#   googletag.cmd.push(function() {
#
#          var mapping = googletag.sizeMapping().
#          addSize([0, 0], []).
#          addSize([200, 300], [[320, 50], [320, 480]]).
#          addSize([450, 300], [[320, 50], [1600, 900]]).
#          addSize([750, 300], [[728, 90], [1600, 900]]).
#          addSize([990, 300], [[1600, 900],[970, 250], [728,90]]).build();
#
#          googletag.defineSlot('/131332370/GeneralTakeover', [[1600, 900], [320, 480]], 'div-gpt-ad-1503491171981-0').
#              defineSizeMapping(mapping).
#              addService(googletag.pubads());
#          googletag.pubads().enableSingleRequest();
#          googletag.enableServices();
#
#          googletag.display('div-gpt-ad-1503491171981-0');
#
#      });
#  </script>
#  <script type="text/javascript">
#  (function(){
#   var adWrap = document.getElementById('div-gpt-ad-1503491171981-0');
#   var closeBtn = document.getElementById('advertClose');
#   var closeLogo = document.getElementById('logoClose');
#
#   closeBtn.addEventListener('click', function( e ){
#    e.preventDefault();
#    adWrap.innerHTML = "";
#    adWrap.style.width = 0;
#    adWrap.style.height = 0;
#   });
#   closeLogo.addEventListener('click', function( e ){
#    e.preventDefault();
#    adWrap.innerHTML = "";
#    adWrap.style.width = 0;
#    adWrap.style.height = 0;
#   });
#  }());
#  </script>
#  </div>
#  <header class="pageHero tabbedHero ">
#  <div class="wrapper col-12">
#  <h1 class="pageTitle">Tables</h1>
#  <div class="tabLinks left" data-script="pl_tabbed" data-tab-class="mainTableTab" data-tab-wrap=".tabs" data-update-tab-param="true" data-widget="tabbed-content">
#  <div class="tabs"></div>
#  </div>
#  <div class="right" data-body="Premier League - Tables" data-render="pagehover" data-script="pl_social-share" data-widget="social-page-share"></div>
#  </div>
#  </header>
#  <div class="mainTableTab" data-compseason="79" data-detail="2" data-filter-list="FIRST" data-script="pl_filtered-list" data-ui-tab="First Team" data-widget="table-filtered">
#  <section class="pageFilter wrapper col-12" data-reset-available="true" data-use-basic-history="true" data-widget="table-filter">
#  </section>
#  <div class="wrapper col-12 tableLogo"><div class="competitionImage1"></div></div>
#  <div class="wrapper col-12">
#  <div class="roundsContainer toggle"></div>
#  <div class="allStructureContainer"></div>
#  </div>
#  <div class="allTablesContainer">
#  <div class="wrapper col-12">
#  <div class="tableContainer">
#  <div class="table wrapper col-12">
#  <table>
#  <summary class="visuallyHidden">This table charts the Premier League teams</summary>
#  <thead>
#  <tr>
#  <th class="revealMoreHeader text-centre" scope="col" style="display:none;">More</th>
#  <th class="text-centre" scope="col">
#  <div class="thFull">Position</div>
#  <div class="thShort">Pos</div>
#  </th>
#  <th class="team" scope="col">Club</th>
#  <th scope="col">
#  <div class="thFull">Played</div>
#  <div class="thShort">Pl</div>
#  </th>
#  <th scope="col">
#  <div class="thFull">Won</div>
#  <div class="thShort">W</div>
#  </th>
#  <th scope="col">
#  <div class="thFull">Drawn</div>
#  <div class="thShort">D</div>
#  </th>
#  <th scope="col">
#  <div class="thFull">Lost</div>
#  <div class="thShort">L</div>
#  </th>
#  <th class="hideSmall" scope="col"><abbr title="Goals For">GF</abbr></th>
#  <th class="hideSmall" scope="col"><abbr title="Goals Against">GA</abbr></th>
#  <th scope="col"><abbr title="Goal Difference">GD</abbr></th>
#  <th class="points" scope="col">
#  <div class="thFull">Points</div>
#  <div class="thShort">Pts</div>
#  </th>
#  <th class="teamForm hideMed" scope="col">Form</th>
#  <th class="hideMed text-centre" scope="col">Next</th>
#  </tr>
#  </thead>
#  <tbody class="tableBodyContainer">
#  <tr class="tableDark" data-compseason="79" data-filtered-entry-size="20" data-filtered-table-row="11" data-filtered-table-row-abbr="11" data-filtered-table-row-name="Manchester City" data-filtered-table-row-opta="t43">
#  <td class="revealMore" role="button" style="display:none;" tabindex="0">
#  <div class="icn chevron-down-g"></div>
#  </td>
#  <td class="pos button-tooltip" id="Tooltip" tabindex="0">
#  <span class="value">1</span>
#  <span class="movement none">
#  <span class="tooltipContainer tooltip-left" role="tooltip">
#  <span class="tooltip-content">Previous Position
#                              <span class="resultHighlight">
#                                  1
#                              </span>
#  </span>
#  </span>
#  </span>
#  </td>
#  <td class="team" scope="row">
#  <a href="/clubs/11/Manchester-City/overview"><span class="badge-25 t43"></span><span class="long">Manchester City</span><span class="short">MCI</span></a>
#  </td>
#  <td>27</td>
#  <td>23</td>
#  <td>3</td>
#  <td>1</td>
#  <td class="hideSmall">79</td>
#  <td class="hideSmall">20</td>
#  <td>
#          +59
#
#   </td>
#  <td class="points">72</td>
#  <td class="form hideMed">
#  <ul>
#  <li class="lose button-tooltip" id="Tooltip" tabindex="0">
#  <abbr class="form-abbreviation" title="Lost">L</abbr>
#  <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/22566" role="tooltip">
#  <span class="tooltip-content">
#  <div class="matchAbridged">
#  <span class="matchInfo">Sunday 14 January 2018</span>
#  <span class="teamName"><abbr title="Liverpool">LIV</abbr></span>
#  <span class="badge-20 t14"></span>
#  <span class="score">4 <span>-</span>3</span>
#  <span class="badge-20 t43"></span>
#  <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
#  <span class="icn arrow-right"></span>
#  </div>
#  </span>
#  </a>
#  </li>
#  <li class="win button-tooltip" id="Tooltip" tabindex="0">
#  <abbr class="form-abbreviation" title="Won">W</abbr>
#  <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/22577" role="tooltip">
#  <span class="tooltip-content">
#  <div class="matchAbridged">
#  <span class="matchInfo">Saturday 20 January 2018</span>
#  <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
#  <span class="badge-20 t43"></span>
#  <span class="score">3 <span>-</span>1</span>
#  <span class="badge-20 t4"></span>
#  <span class="teamName"><abbr title="Newcastle United">NEW</abbr></span>
#  <span class="icn arrow-right"></span>
#  </div>
#  </span>
#  </a>
#  </li>
#  <li class="win button-tooltip" id="Tooltip" tabindex="0">
#  <abbr class="form-abbreviation" title="Won">W</abbr>
#  <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/22587" role="tooltip">
#  <span class="tooltip-content">
#  <div class="matchAbridged">
#  <span class="matchInfo">Wednesday 31 January 2018</span>
#  <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
#  <span class="badge-20 t43"></span>
#  <span class="score">3 <span>-</span>0</span>
#  <span class="badge-20 t35"></span>
#  <span class="teamName"><abbr title="West Bromwich Albion">WBA</abbr></span>
#  <span class="icn arrow-right"></span>
#  </div>
#  </span>
#  </a>
#  </li>
#  <li class="draw button-tooltip" id="Tooltip" tabindex="0">
#  <abbr class="form-abbreviation" title="Drawn">D</abbr>
#  <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/22595" role="tooltip">
#  <span class="tooltip-content">
#  <div class="matchAbridged">
#  <span class="matchInfo">Saturday 3 February 2018</span>
#  <span class="teamName"><abbr title="Burnley">BUR</abbr></span>
#  <span class="badge-20 t90"></span>
#  <span class="score">1 <span>-</span>1</span>
#  <span class="badge-20 t43"></span>
#  <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
#  <span class="icn arrow-right"></span>
#  </div>
#  </span>
#  </a>
#  </li>
#  <li class="win button-tooltip" id="Tooltip" tabindex="0">
#  <abbr class="form-abbreviation" title="Won">W</abbr>
#  <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/22605" role="tooltip">
#  <span class="tooltip-content">
#  <div class="matchAbridged">
#  <span class="matchInfo">Saturday 10 February 2018</span>
#  <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
#  <span class="badge-20 t43"></span>
#  <span class="score">5 <span>-</span>1</span>
#  <span class="badge-20 t13"></span>
#  <span class="teamName"><abbr title="Leicester City">LEI</abbr></span>
#  <span class="icn arrow-right"></span>
#  </div>
#  </span>
#  </a>
#  </li>
#  </ul>
#  <td class="nextMatchCol hideMed">
#  <span class="button-tooltip" id="Tooltip" tabindex="0">
#  <span class="nextMatch"><span class="badge-20 t3"><span class="visuallyHidden">Arsenal</span></span></span>
#  <a class="tooltipContainer linkable tooltip-link tooltip-right" href="/match/22612" role="tooltip">
#  <span class="tooltip-content">
#  <div class="matchAbridged">
#  <span class="matchInfo">Thursday 01 March 2018</span>
#  <span class="teamName"><abbr title="Arsenal">ARS</abbr></span>
#  <span class="badge-20 t3"></span>
#  <time>19:45</time>
#  <span class="badge-20 t43"></span>
#  <span class="teamName"><abbr title="Manchester City">MCI</abbr></span>
#  <span class="icn arrow-right"></span>
#  </div></span>
#  </a></span></td></td></tr></tbody></table></div>
#  </div></div></div></div></main>]

# %%
my_titles = soup.select(
    'h3 > a'
    )

data = {}

for title in my_titles:
    data[title.text] = title.get('href')

with open(os.path.join(BASE_DIR, 'result.json'), 'w+') as json_file:
    json.dump(data, json_file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-cc97ca0d3123> in <module>()
#       8     data[title.text] = title.get('href')
#       9
# ---> 10 with open(os.path.join(BASE_DIR, 'result.json'), 'w+') as json_file:
#      11     json.dump(data, json_file)
#
# NameError: name 'BASE_DIR' is not defined
