# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Quiz
# - 타이타닉 데이터를 가져와서 연령대별 생존률을 구하세요

# %%
# 타이타닉 데이터 가져오기

# %%
titanic = pd.read_csv('train.csv')
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# ["Survived","Age"] 컬럼을 가지는 titanic_df 데이터 프레임을 만들고 Age가 NaN인 row 데이터를 삭제

# %%
titanic_df = titanic.loc[:,["Survived","Age"]]
titanic_df = titanic_df.dropna()
titanic_df = titanic_df.reset_index(drop=True)
titanic_df.tail()
# Out:
#      Survived   Age
# 709         0  39.0
# 710         0  27.0
# 711         1  19.0
# 712         1  26.0
# 713         0  32.0

# %%
# Ages 컬럼을 만들고 Ages 컬럼에는 연령대에 대한 데이터 삽입

# %%
def ages(age):
    return (age // 10) * 10

titanic_df["Ages"] = titanic_df["Age"].apply(ages).astype("int")
titanic_df["Age"] = titanic_df["Age"].astype("int")
titanic_df.tail()
# Out:
#      Survived  Age  Ages
# 709         0   39    30
# 710         0   27    20
# 711         1   19    10
# 712         1   26    20
# 713         0   32    30

# %%
# 연령대별로 생존률

# %%
titanic_df["Count"] = 1
titanic_df2 = titanic_df.pivot_table(values="Count", index=["Ages"], columns=["Survived"], aggfunc=np.sum)
titanic_df2
# Out:
# Survived      0     1
# Ages
# 0          24.0  38.0
# 10         61.0  41.0
# 20        143.0  77.0
# 30         94.0  73.0
# 40         55.0  34.0
# 50         28.0  20.0
# 60         13.0   6.0
# 70          6.0   NaN
# 80          NaN   1.0

# %%
non_survived = titanic_df2[0]
survived = titanic_df2[1]
titanic_df2["survived_rate"] = round( ( survived / (non_survived + survived) ) * 100, 2)
titanic_df2
# Out:
# Survived      0     1  survived_rate
# Ages
# 0          24.0  38.0          61.29
# 10         61.0  41.0          40.20
# 20        143.0  77.0          35.00
# 30         94.0  73.0          43.71
# 40         55.0  34.0          38.20
# 50         28.0  20.0          41.67
# 60         13.0   6.0          31.58
# 70          6.0   NaN            NaN
# 80          NaN   1.0            NaN

# %%
titanic_df2.dropna(inplace=True)
titanic_df2
# Out:
# Survived      0     1  survived_rate
# Ages
# 0          24.0  38.0          61.29
# 10         61.0  41.0          40.20
# 20        143.0  77.0          35.00
# 30         94.0  73.0          43.71
# 40         55.0  34.0          38.20
# 50         28.0  20.0          41.67
# 60         13.0   6.0          31.58

# %%
# 컬럼명을 변경하고 연령대별 생존, 사망, 생존률 그래프 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
titanic_df3 = titanic_df2.rename({0:"non_survived", 1:"survived"})
titanic_df3
# Out:
# Survived          0     1  survived_rate
# Ages
# non_survived   24.0  38.0          61.29
# 10             61.0  41.0          40.20
# 20            143.0  77.0          35.00
# 30             94.0  73.0          43.71
# 40             55.0  34.0          38.20
# 50             28.0  20.0          41.67
# 60             13.0   6.0          31.58

# %%
titanic_df3.plot()
plt.legend(loc='best')
plt.show()
