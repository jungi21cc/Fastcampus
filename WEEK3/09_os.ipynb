# %% [markdown]
# ### OS

# %%
import os

# %% [markdown]
# ##### 디렉토리 만들기
# - os_dir 이라는 디렉토리를 만든다.

# %%
os.makedirs("os_dir")

# %%
# !ls
# Out:
# 09_os.ipynb  10_thread.ipynb  os_dir  practice week3.ipynb

# %% [markdown]
# ##### write
# - 파일 쓰기
# - 앞에서 배운 방법으로 txt와 csv 파일을 작성합니다.

# %%
s = "data science"

with open("os_dir/test.txt", "wt") as f:
    f.write(s)
    
s2 = "data science2"
with open("os_dir/test2.txt", "wt") as f:
    f.write(s)
    
s3 = "data,science2"
with open("os_dir/test3.csv", "wt") as f:
    f.write(s)

# %%
s = "data science"
with open("os_dir/test.txt", "wt") as f:
    f.write(s)
    
s2 = "data science2"
with open("os_dir/test2.txt", "wt") as f:
    f.write(s)
    
s3 = "data,science2"
with open("os_dir/test3.csv", "wt") as f:
    f.write(s)

# %%
# !ls os_dir
# Out:
# test2.txt  test3.csv  test.txt

# %% [markdown]
# ##### listdir
# - 파일 리스트 읽기
# - 특정 확장자를 가진 파일을 뽑아낸다.

# %%
# 파일 리스트 읽기
file_list = os.listdir("os_dir")
print(file_list)
# Out:
# ['test3.csv', 'test.txt', 'test2.txt']

# %%
# txt 파일 리스트만 호출
result_1 = [ file_name for file_name in file_list if file_name.endswith(".txt") ]
print(result_1)
# Out:
# ['test.txt', 'test2.txt']

# %%
# txt 파일이 아닌 파일 리스트만 호출
result_2 = [ file_name for file_name in file_list if not file_name.endswith(".txt") ]
print(result_2)
# Out:
# ['test3.csv']

# %% [markdown]
# ##### remove
# - 파일 삭제

# %%
file_name = 'test3.csv'
os.remove("os_dir/" + file_name)

# %%
# !ls os_dir
# Out:
# test2.txt  test.txt

# %%
# for 반복문을 사용하여 모든 파일을 삭제할수 있다.
file_list = os.listdir("os_dir")
for file_name in file_list:
    os.remove("os_dir/" + file_name)

# %%
def remove_all_files(path):
    file_list = os.listdir("os_dir")
    for file_name in file_list:
        os.remove("os_dir/" + file_name)

# %%
# !ls os_dir

# %% [markdown]
# ##### removedirs
# - 디렉토리 삭제

# %%
# !ls os_dir
# Out:
# test2.txt  test3.csv  test.txt

# %%
# 내부에 파일이 있으면 삭제되지 않는다.

os.removedirs("os_dir")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-43-63b4562b366e> in <module>()
#       1 # 내부에 파일이 있으면 삭제되지 않는다.
#       2
# ----> 3 os.removedirs("os_dir")
#
# ~/enter/lib/python3.6/os.py in removedirs(name)
#     236
#     237     """
# --> 238     rmdir(name)
#     239     head, tail = path.split(name)
#     240     if not tail:
#
# OSError: [Errno 39] Directory not empty: 'os_dir'

# %%
# 파일과 디렉토리 모두 삭제
import shutil
shutil.rmtree('os_dir')

# %%
# !ls os_dir
# Out:
# ls: cannot access 'os_dir': No such file or directory

# %% [markdown]
# ##### exists
# - 존재여부 확인하기

# %%
# !ls os_dir
# Out:
# test2.txt  test3.csv  test.txt

# %%
os.path.exists("os_dir/test.txt")
# Out:
# True

# %%
os.path.exists("os_dir/test4.txt")
# Out:
# False

# %% [markdown]
# ##### isfile
# - 타입이 파일인지 확인하기

# %%
os.path.isfile("os_dir/test.txt")
# Out:
# True

# %%
os.path.isfile("os_dir")
# Out:
# False

# %% [markdown]
# ##### isdir
# - 타입이 디렉토리인지 확인하기

# %%
os.path.isdir("os_dir/test.txt")
# Out:
# False

# %%
os.path.isdir("os_dir")
# Out:
# True

# %% [markdown]
# ##### copy
# - 복사하기

# %%
import shutil
shutil.copy("os_dir/test.txt", "os_dir/copy.txt")
# Out:
# 'os_dir/copy.txt'

# %%
os.path.isfile("os_dir/copy.txt")
# Out:
# True

# %%
# !ls os_dir
# Out:
# copy.txt  test2.txt  test3.csv	test.txt

# %% [markdown]
# ##### rename
# - 이름바꾸기

# %%
# !ls os_dir
# Out:
# rename.txt  test2.txt  test3.csv  test.txt

# %%
os.rename("os_dir/copy.txt", "os_dir/rename.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-76-5404e6b61a19> in <module>()
# ----> 1 os.rename("os_dir/copy.txt", "os_dir/rename.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'os_dir/copy.txt' -> 'os_dir/rename.txt'

# %%
os.path.isfile("os_dir/copy.txt")
# Out:
# False

# %%
os.path.isfile("os_dir/rename.txt")
# Out:
# True

# %%
# !ls os_dir
# Out:
# rename.txt  test2.txt  test3.csv  test.txt

# %% [markdown]
# ##### chmod
# - 권한 설정
# - 타입[:1], 소유자[1:4] 그룹[4:7] 공개[7:]
# - r(read), w(write), x(excute)

# %%
# 8진수 octet : 7(8) -> 111(2), 4(8) -> 100(2)
os.chmod("os_dir/rename.txt", 0o444) # 모든 사용자 read 권한만 갖도록 (-rw-r--r--) -> (-r--r--r--)

# %%
os.chmod("os_dir/rename.txt", 0o644) # 파일 소유자는 작성권한을 갖도록  (-r--r--r--) -> (-rw-r--r--)

# %%
os.chmod("os_dir/rename.txt", 0o000) # 모든권한제거  (-rw-r--r--) -> (----------)
